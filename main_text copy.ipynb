# %%
from text_processor import TextProcessor
from kg_processor import create_kg, create_map, merge_map
from visualization import generate_html
from config import FILE_PATHS
from text_processor import TextProcessor
from kg_processor import create_kg, create_map, merge_map

import argparse
input_file = "passage copy/俄乌冲突与国际政治经济博弈笔谈_赵隆.md"
output_file = input_file.replace('.md', '.html')
processor = TextProcessor()
processor.parse_file(input_file)
kg = create_kg()
create_map(processor.root,kg)
merge_map(processor.root,kg)
# Out:
# 2025/06/24 13:04:11 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# 2025/06/24 13:06:48 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# 2025/06/24 13:19:46 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# 2025/06/24 13:19:53 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:110, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream)
#     109 try:
# --> 110     response = sync_httpx_client.post(
#     111         url=api_base,
#     112         headers=headers,
#     113         data=json.dumps(data),
#     114         timeout=timeout,
#     115         stream=stream,
#     116         logging_obj=logging_obj,
#     117     )
#     118 except httpx.HTTPStatusError as e:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\llms\custom_httpx\http_handler.py:559, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     558 except Exception as e:
# --> 559     raise e
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\llms\custom_httpx\http_handler.py:537, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     534     req = self.client.build_request(
#     535         "POST", url, data=data, json=json, params=params, headers=headers, files=files, content=content  # type: ignore
#     536     )
# --> 537 response = self.client.send(req, stream=stream)
#     538 response.raise_for_status()
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\main.py:1412, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1406         logging.post_call(
#    1407             input=messages,
#    1408             api_key=api_key,
#    1409             original_response=str(e),
#    1410             additional_args={"headers": headers},
#    1411         )
# -> 1412         raise e
#    1414 elif custom_llm_provider == "azure_ai":
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\main.py:1387, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1386 try:
# -> 1387     response = base_llm_http_handler.completion(
#    1388         model=model,
#    1389         messages=messages,
#    1390         headers=headers,
#    1391         model_response=model_response,
#    1392         api_key=api_key,
#    1393         api_base=api_base,
#    1394         acompletion=acompletion,
#    1395         logging_obj=logging,
#    1396         optional_params=optional_params,
#    1397         litellm_params=litellm_params,
#    1398         timeout=timeout,  # type: ignore
#    1399         client=client,
#    1400         custom_llm_provider=custom_llm_provider,
#    1401         encoding=encoding,
#    1402         stream=stream,
#    1403     )
#    1404 except Exception as e:
#    1405     ## LOGGING - log the original exception returned
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:368, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client)
#     366     sync_httpx_client = client
# --> 368 response = self._make_common_sync_call(
#     369     sync_httpx_client=sync_httpx_client,
#     370     provider_config=provider_config,
#     371     api_base=api_base,
#     372     headers=headers,
#     373     data=data,
#     374     timeout=timeout,
#     375     litellm_params=litellm_params,
#     376     logging_obj=logging_obj,
#     377 )
#     378 return provider_config.transform_response(
#     379     model=model,
#     380     raw_response=response,
#    (...)
#     389     json_mode=json_mode,
#     390 )
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:133, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream)
#     132 except Exception as e:
# --> 133     raise self._handle_error(e=e, provider_config=provider_config)
#     134 break
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:970, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#     969     error_headers = {}
# --> 970 raise provider_config.get_error_class(
#     971     error_message=error_text,
#     972     status_code=status_code,
#     973     headers=error_headers,
#     974 )
#
# OpenAIError: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\utils.py:1091, in client.<locals>.wrapper(*args, **kwargs)
#    1090 # MODEL CALL
# -> 1091 result = original_function(*args, **kwargs)
#    1092 end_time = datetime.datetime.now()
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\main.py:3093, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3091 except Exception as e:
#    3092     ## Map to OpenAI Exception
# -> 3093     raise exception_type(
#    3094         model=model,
#    3095         custom_llm_provider=custom_llm_provider,
#    3096         original_exception=e,
#    3097         completion_kwargs=args,
#    3098         extra_kwargs=kwargs,
#    3099     )
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2214, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2213     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2214     raise e
#    2215 else:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:455, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     454         exception_mapping_worked = True
# --> 455         raise APIError(
#     456             status_code=original_exception.status_code,
#     457             message=f"APIError: {exception_provider} - {message}",
#     458             llm_provider=custom_llm_provider,
#     459             model=model,
#     460             request=getattr(original_exception, "request", None),
#     461             litellm_debug_info=extra_information,
#     462         )
#     463 else:
#     464     # if no status code then it is an APIConnectionError: https://github.com/openai/openai-python#handling-errors
#     465     # exception_mapping_worked = True
#
# APIError: litellm.APIError: APIError: DeepseekException - [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\adapters\json_adapter.py:69, in JSONAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      68     lm_kwargs["response_format"] = {"type": "json_object"}
# ---> 69     return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      70 except AdapterParseError as e:
#      71     # On AdapterParseError, we raise the original error.
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\adapters\chat_adapter.py:50, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      47 if isinstance(e, ContextWindowExceededError) or isinstance(self, JSONAdapter):
#      48     # On context window exceeded error or already using JSONAdapter, we don't want to retry with a different
#      49     # adapter.
# ---> 50     raise e
#      51 return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\adapters\chat_adapter.py:42, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      41 try:
# ---> 42     return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      43 except Exception as e:
#      44     # fallback to JSONAdapter
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\adapters\base.py:51, in Adapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      49 inputs = self.format(signature, demos, inputs)
# ---> 51 outputs = lm(messages=inputs, **lm_kwargs)
#      52 return self._call_post_process(outputs, signature)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\clients\base_lm.py:88, in BaseLM.__call__(self, prompt, messages, **kwargs)
#      86 @with_callbacks
#      87 def __call__(self, prompt=None, messages=None, **kwargs):
# ---> 88     response = self.forward(prompt=prompt, messages=messages, **kwargs)
#      89     outputs = self._process_lm_response(response, prompt, messages, **kwargs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\clients\lm.py:127, in LM.forward(self, prompt, messages, **kwargs)
#     125 completion, litellm_cache_args = self._get_cached_completion_fn(completion, cache, enable_memory_cache)
# --> 127 results = completion(
#     128     request=dict(model=self.model, messages=messages, **kwargs),
#     129     num_retries=self.num_retries,
#     130     cache=litellm_cache_args,
#     131 )
#     133 if any(c.finish_reason == "length" for c in results["choices"]):
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\clients\cache.py:232, in request_cache.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     231 # Otherwise, compute and store the result
# --> 232 result = fn(*args, **kwargs)
#     233 # `enable_memory_cache` can be provided at call time to avoid indefinite growth.
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\clients\lm.py:304, in litellm_completion(request, num_retries, cache)
#     303 if stream_completion is None:
# --> 304     return litellm.completion(
#     305         cache=cache,
#     306         num_retries=num_retries,
#     307         retry_strategy="exponential_backoff_retry",
#     308         **request,
#     309     )
#     311 return stream_completion()
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\utils.py:1193, in client.<locals>.wrapper(*args, **kwargs)
#    1192         kwargs["num_retries"] = num_retries
# -> 1193         return litellm.completion_with_retries(*args, **kwargs)
#    1194 elif (
#    1195     isinstance(e, litellm.exceptions.ContextWindowExceededError)
#    1196     and context_window_fallback_dict
#    1197     and model in context_window_fallback_dict
#    1198     and not _is_litellm_router_call
#    1199 ):
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\main.py:3131, in completion_with_retries(*args, **kwargs)
#    3128     retryer = tenacity.Retrying(
#    3129         stop=tenacity.stop_after_attempt(num_retries), reraise=True
#    3130     )
# -> 3131 return retryer(original_function, *args, **kwargs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\utils.py:1213, in client.<locals>.wrapper(*args, **kwargs)
#    1210     logging_obj.failure_handler(
#    1211         e, traceback_exception, start_time, end_time
#    1212     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1213 raise e
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\utils.py:1091, in client.<locals>.wrapper(*args, **kwargs)
#    1090 # MODEL CALL
# -> 1091 result = original_function(*args, **kwargs)
#    1092 end_time = datetime.datetime.now()
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\main.py:3093, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3091 except Exception as e:
#    3092     ## Map to OpenAI Exception
# -> 3093     raise exception_type(
#    3094         model=model,
#    3095         custom_llm_provider=custom_llm_provider,
#    3096         original_exception=e,
#    3097         completion_kwargs=args,
#    3098         extra_kwargs=kwargs,
#    3099     )
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2214, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2213     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2214     raise e
#    2215 else:
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:455, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     454         exception_mapping_worked = True
# --> 455         raise APIError(
#     456             status_code=original_exception.status_code,
#     457             message=f"APIError: {exception_provider} - {message}",
#     458             llm_provider=custom_llm_provider,
#     459             model=model,
#     460             request=getattr(original_exception, "request", None),
#     461             litellm_debug_info=extra_information,
#     462         )
#     463 else:
#     464     # if no status code then it is an APIConnectionError: https://github.com/openai/openai-python#handling-errors
#     465     # exception_mapping_worked = True
#
# APIError: litellm.APIError: APIError: DeepseekException - [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 14
#      12 processor.parse_file(input_file)
#      13 kg = create_kg()
# ---> 14 create_map(processor.root,kg)
#      15 merge_map(processor.root,kg)
#
# File c:\Users\wzj\OneDrive\Desktop\论文\kg_processor.py:32, in create_map(node, kg)
#      30 def create_map(node, kg):
#      31     for child in node.get_children():
# ---> 32         create_map(child, kg)
#      33     if not node.children:
#      34         build_graph(node, kg)
#
# File c:\Users\wzj\OneDrive\Desktop\论文\kg_processor.py:32, in create_map(node, kg)
#      30 def create_map(node, kg):
#      31     for child in node.get_children():
# ---> 32         create_map(child, kg)
#      33     if not node.children:
#      34         build_graph(node, kg)
#
# File c:\Users\wzj\OneDrive\Desktop\论文\kg_processor.py:32, in create_map(node, kg)
#      30 def create_map(node, kg):
#      31     for child in node.get_children():
# ---> 32         create_map(child, kg)
#      33     if not node.children:
#      34         build_graph(node, kg)
#
# File c:\Users\wzj\OneDrive\Desktop\论文\kg_processor.py:34, in create_map(node, kg)
#      32     create_map(child, kg)
#      33 if not node.children:
# ---> 34     build_graph(node, kg)
#
# File c:\Users\wzj\OneDrive\Desktop\论文\kg_processor.py:18, in build_graph(node, kg)
#      16 def build_graph(node, kg):
#      17     text = clean_text(node.get_text())
# ---> 18     graph = kg.generate(input_data=text, context=node.get_name())
#      19     node.graph = graph
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\kg_gen\kg_gen.py:134, in KGGen.generate(self, input_data, model, api_key, api_base, context, chunk_size, cluster, temperature, output_folder)
#     132 if not chunk_size:
#     133   entities = get_entities(self.dspy, processed_input, is_conversation=is_conversation)
# --> 134   relations = get_relations(self.dspy, processed_input, entities, is_conversation=is_conversation)
#     135 else:
#     136   chunks = chunk_text(processed_input, chunk_size)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\kg_gen\steps\_2_get_relations.py:68, in get_relations(dspy, input_data, entities, is_conversation, context)
#      66 Relation, ExtractRelations = fallback_extraction_sig(entities, is_conversation, context)
#      67 extract = dspy.Predict(ExtractRelations)
# ---> 68 result = extract(source_text=input_data, entities=entities)
#      70 class FixedRelations(dspy.Signature):
#      71   """Fix the relations so that every subject and object of the relations are exact matches to an entity. Keep the predicate the same. The meaning of every relation should stay faithful to the reference text. If you cannot maintain the meaning of the original relation relative to the source text, then do not return it."""
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\predict\predict.py:85, in Predict.__call__(self, *args, **kwargs)
#      82 if args:
#      83     raise ValueError(self._get_positional_args_error_message())
# ---> 85 return super().__call__(**kwargs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\primitives\program.py:32, in Module.__call__(self, *args, **kwargs)
#      29         output.set_lm_usage(usage_tracker.get_total_tokens())
#      30         return output
# ---> 32 return self.forward(*args, **kwargs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\predict\predict.py:146, in Predict.forward(self, **kwargs)
#     144 else:
#     145     with settings.context(send_stream=None):
# --> 146         completions = adapter(lm, lm_kwargs=config, signature=signature, demos=demos, inputs=kwargs)
#     148 return self._forward_postprocess(completions, signature, **kwargs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\adapters\chat_adapter.py:51, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      47 if isinstance(e, ContextWindowExceededError) or isinstance(self, JSONAdapter):
#      48     # On context window exceeded error or already using JSONAdapter, we don't want to retry with a different
#      49     # adapter.
#      50     raise e
# ---> 51 return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#
# File c:\Users\wzj\.conda\envs\kg_new\lib\site-packages\dspy\adapters\json_adapter.py:75, in JSONAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      72     raise e
#      73 except Exception as e:
#      74     # On any other error, we raise a RuntimeError with the original error message.
# ---> 75     raise RuntimeError(
#      76         "Both structured output format and JSON mode failed. Please choose a model that supports "
#      77         f"`response_format` argument. Original error: {e}"
#      78     ) from e
#
# RuntimeError: Both structured output format and JSON mode failed. Please choose a model that supports `response_format` argument. Original error: litellm.APIError: APIError: DeepseekException - [Errno 11001] getaddrinfo failed

# %%
generate_html(processor.root, output_file)
